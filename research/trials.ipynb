# %%
d ={'key1': 'value1', 'key2': 'value2'}

# %%
d
# Out:
# {'key1': 'value1', 'key2': 'value2'}

# %%
d.key1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 d.key1
#
# AttributeError: 'dict' object has no attribute 'key1'

# %%
from box import ConfigBox

# %%
d2 = ConfigBox(d)

# %%
d2
# Out:
# ConfigBox({'key1': 'value1', 'key2': 'value2'})

# %%
d2.key1
# Out:
# 'value1'

# %%
def product_two(number1: int, number2: int) -> int:
    return number1 * number2

# %%
product_two(2, 3)
# Out:
# 6

# %%
product_two(2, "3")
# Out:
# '33'

# %%
from beartype import beartype as ensure_annotations

# %%
@ensure_annotations
def product_two(number1: int, number2: int) -> int:
    return number1 * number2

# %%
product_two(2, 3)
# Out:
# 6

# %%
product_two(2, "3")
# Out:
# ---------------------------------------------------------------------------
# BeartypeCallHintParamViolation            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 product_two(2, "3")
#
# File <@beartype(__main__.product_two) at 0x1a2c4bffc40>:46, in product_two(__beartype_get_violation, __beartype_conf, __beartype_check_meta, __beartype_func, *args, **kwargs)
#
# BeartypeCallHintParamViolation: Function __main__.product_two() parameter number2='3' violates type hint <class 'int'>, as str '3' not instance of int.
